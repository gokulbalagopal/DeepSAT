# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data processing

# %%
x_train = pd.read_csv("X_train_sat4.csv", chunksize=1000)
  
for data_x_train in x_train:
    print(data_x_train)
    print(data_x_train.shape)
    break
reshaped_x_train = data_x_train.values.reshape(1000, 28,28,4)
print(reshaped_x_train)

############### Loading Y train ################
y_train = pd.read_csv("y_train_sat4.csv", chunksize=1000)
  
for data_y_train in y_train:
    print(data_y_train)
    print(data_y_train.shape)
    break
# Out:
#      104  103   94  133  114  115  106  145  104.1  110  ...  95.63  141.21  \
# 0    175  149  130  146  169  148  130  141    166  139  ...    119     132
# 1    113  114  105  163  126  131  125  176    119  125  ...    129     177
# 2    107  104  100  124  108  105  102  126    105  104  ...     74      85
# 3    105  100   95  132   77   72   62  114     76   77  ...     86     129
# 4    151  128  100  190  143  124   97  185    161  142  ...    115     190
# ..   ...  ...  ...  ...  ...  ...  ...  ...    ...  ...  ...    ...     ...
# 995   94   98   95   78   74   78   59   51     95  104  ...    105      88
# 996  157  148  151  108  156  146  151  112    170  164  ...    118     179
# 997  138  130  127  190  124  105   98  174    134  106  ...     88     125
# 998  231  225  194  210  229  220  191  208    228  217  ...    154     205
# 999  117  106  105  143   96   98   95  131     93  104  ...     92     148
#
# ...
